# %% [markdown]
# ### Competiion 1 -Group 5

# %% [markdown]
# ### Used Car Prices in India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
from pandas import Series, DataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 1. Reading the dataset into the Python Environment:

# %%
dataset = pd.read_csv('cardekho_updated.csv')
dataset.head(5)
# Out:
#                                         full_name selling_price  \
# 0                                 Maruti Alto Std     1.2 Lakh*
# 1                          Hyundai Grand i10 Asta     5.5 Lakh*
# 2                                Hyundai i20 Asta    2.15 Lakh*
# 3                   Maruti Alto K10 2010-2014 VXI    2.26 Lakh*
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV     5.7 Lakh*
#
#                                         new_price  year seller_type  \
# 0                                             NaN  2012  Individual
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016  Individual
# 2                                             NaN  2010  Individual
# 3                                             NaN  2012  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015      Dealer
#
#       km_driven   owner_type fuel_type transmission_type            mileage  \
# 0  1,20,000 kms  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1    20,000 kms  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2    60,000 kms  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3    37,000 kms  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4    30,000 kms  First Owner    Diesel            Manual  Mileage22.77 kmpl
#
#           engine           max_power   seats
# 0   Engine796 CC   Max Power46.3 bhp  Seats5
# 1  Engine1197 CC     Max Power82 bhp  Seats5
# 2  Engine1197 CC     Max Power80 bhp  Seats5
# 3   Engine998 CC   Max Power67.1 bhp  Seats5
# 4  Engine1498 CC  Max Power98.59 bhp  Seats5

# %% [markdown]
# #### Checking the basic details of the dataset:

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19974 entries, 0 to 19973
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19974 non-null  object
#  1   selling_price      19974 non-null  object
#  2   new_price          9564 non-null   object
#  3   year               19974 non-null  int64
#  4   seller_type        19974 non-null  object
#  5   km_driven          19974 non-null  object
#  6   owner_type         19974 non-null  object
#  7   fuel_type          19974 non-null  object
#  8   transmission_type  19974 non-null  object
#  9   mileage            19814 non-null  object
#  10  engine             19864 non-null  object
#  11  max_power          19637 non-null  object
#  12  seats              19887 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.0+ MB

# %%
dataset.shape
# Out:
# (19974, 13)

# %%
dataset.describe(include = 'all')
# Out:
#                      full_name selling_price  \
# count                    19974         19974
# unique                    3321          1215
# top     Maruti Swift Dzire VDI     4.5 Lakh*
# freq                       210           466
# mean                       NaN           NaN
# std                        NaN           NaN
# min                        NaN           NaN
# 25%                        NaN           NaN
# 50%                        NaN           NaN
# 75%                        NaN           NaN
# max                        NaN           NaN
#
#                                              new_price          year  \
# count                                             9564  19974.000000
# unique                                            1744           NaN
# top     New Car (On-Road Price) : Rs.12.68-16.80 Lakh*           NaN
# freq                                               144           NaN
# mean                                               NaN   2014.526134
# std                                                NaN      3.248791
# min                                                NaN   1991.000000
# 25%                                                NaN   2013.000000
# 50%                                                NaN   2015.000000
# 75%                                                NaN   2017.000000
# max                                                NaN   2021.000000
#
#        seller_type   km_driven   owner_type fuel_type transmission_type  \
# count        19974       19974        19974     19974             19974
# unique           3        4515            1         5                 2
# top         Dealer  50,000 kms  First Owner    Diesel            Manual
# freq         11970         750        19974      9815             16025
# mean           NaN         NaN          NaN       NaN               NaN
# std            NaN         NaN          NaN       NaN               NaN
# min            NaN         NaN          NaN       NaN               NaN
# 25%            NaN         NaN          NaN       NaN               NaN
# 50%            NaN         NaN          NaN       NaN               NaN
# 75%            NaN         NaN          NaN       NaN               NaN
# max            NaN         NaN          NaN       NaN               NaN
#
#                  mileage         engine        max_power   seats
# count              19814          19864            19637   19887
# unique               561            169              493       9
# top     Mileage18.9 kmpl  Engine1197 CC  Max Power74 bhp  Seats5
# freq                 624           2662              867   16585
# mean                 NaN            NaN              NaN     NaN
# std                  NaN            NaN              NaN     NaN
# min                  NaN            NaN              NaN     NaN
# 25%                  NaN            NaN              NaN     NaN
# 50%                  NaN            NaN              NaN     NaN
# 75%                  NaN            NaN              NaN     NaN
# max                  NaN            NaN              NaN     NaN

# %% [markdown]
# #### Checking the missing values in te dataset

# %%
dataset.isna().sum()
# Out:
# full_name                0
# selling_price            0
# new_price            10410
# year                     0
# seller_type              0
# km_driven                0
# owner_type               0
# fuel_type                0
# transmission_type        0
# mileage                160
# engine                 110
# max_power              337
# seats                   87
# dtype: int64

# %% [markdown]
# ### Insights:
#
#           The dataset consist of 19974 rows and 13 columns.
#           It has more object type features and one numerical variable in the columns.
#           There are missing values in the features like new_price, mileage,engine, max_power and seats.

# %% [markdown]
# ### 2. Preprocessing steps :

# %% [markdown]
# #### 1. Cleaning the data :

# %%
dataset.dtypes
# Out:
# full_name            object
# selling_price        object
# new_price            object
# year                  int64
# seller_type          object
# km_driven            object
# owner_type           object
# fuel_type            object
# transmission_type    object
# mileage              object
# engine               object
# max_power            object
# seats                object
# dtype: object

# %%
for i in range(dataset.shape[0]):
    try:
        price = float(dataset['selling_price'][i].split(' ')[0])
        digit = dataset['selling_price'][i].split(' ')[1]
        #price = float(dataset['selling_price'][i])
        #digit = dataset['selling_price'][i]
        if digit == 'Lakh*':
            price = price * 100000
            dataset['selling_price'][i] = price
        elif digit == 'Cr*':
            price = price * 10000000
            dataset['selling_price'][i] = price
    except:
        price = dataset['selling_price'][i][:-1]
        price = price.replace(',', '')
        dataset['selling_price'][i] = float(price)
#dataset

# %%
## Converting the feature selling_price into float:

dataset['selling_price'] = dataset['selling_price'].astype(float, errors = 'raise')

dataset.dtypes
# Out:
# full_name             object
# selling_price        float64
# new_price             object
# year                   int64
# seller_type           object
# km_driven             object
# owner_type            object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# dtype: object

# %%
## Converting the some of the required fetures from object into float that matters the predicting feature - 'Selling Price'

dataset['km_driven'] = dataset['km_driven'].str.split(' ', n=1, expand=True)[0]
dataset['km_driven'] = dataset['km_driven'].str.replace(',','')

# %%
dataset['km_driven']= dataset['km_driven'].astype(float, errors = 'raise')

# %%
dataset.dtypes
# Out:
# full_name             object
# selling_price        float64
# new_price             object
# year                   int64
# seller_type           object
# km_driven            float64
# owner_type            object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# dtype: object

# %% [markdown]
# ### 2. Filling the missing values in the dataset:

# %%
obj_cols = list(dataset.select_dtypes('object').columns)
for o in obj_cols:
    dataset[o].fillna("NULL",inplace = True)

# %%
obj_cols = list(dataset.select_dtypes('float').columns)
for o in obj_cols:
   dataset[o].fillna('NULL',inplace = True)

# %%
dataset.isna().sum()
# Out:
# full_name            0
# selling_price        0
# new_price            0
# year                 0
# seller_type          0
# km_driven            0
# owner_type           0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# dtype: int64

# %% [markdown]
# #### Insights:
#
#              We have filled the missing values in the dataset.

# %% [markdown]
# ### 3. Outlier Detection and Handling:

# %% [markdown]
# a. Checking the Outliers in the dataset:
#
#         Inorder to check the outliers, we need to plot boxplot of the features using percentiles.

# %%
### Box ploting the features which has outliers:

plt.figure(figsize=(10,5))
dataset.boxplot()
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3]),
#  [Text(1, 0, 'selling_price'), Text(2, 0, 'year'), Text(3, 0, 'km_driven')])

# %% [markdown]
# ###### b. Handling outliers in 'year' variable

# %%
### Handling outliers in 'year' variable

plt.boxplot(dataset['year'])
plt.title('Box plot of year')
# Out:
# Text(0.5, 1.0, 'Box plot of year')

# %%
Q1=np.percentile(dataset['year'], 25, interpolation = 'midpoint')
Q2=np.percentile(dataset['year'], 50, interpolation = 'midpoint')
Q3=np.percentile(dataset['year'], 75, interpolation = 'midpoint')
print("Q1 is : ", Q1)
print("Q2 is : ",Q2)
print("Q3 is : ",Q3)
# Out:
# Q1 is :  2013.0
# Q2 is :  2015.0
# Q3 is :  2017.0

# %%
dataset['year'].median()
# Out:
# 2015.0

# %%
IQR= Q3 - Q1
low_lim = Q1 - 1.5* IQR
up_lim = Q3 + 1.5 * IQR


print("IQR is : ",IQR)
print("Lower Limit is :",round(low_lim))
print("Upper limit is: ",round(up_lim))
# Out:
# IQR is :  4.0
# Lower Limit is : 2007
# Upper limit is:  2023

# %%
outlier=[]
for x in dataset['year']:
    if((x>up_lim) or(x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [2004,
#  2006,
#  2006,
#  2000,
#  2004,
#  2005,
#  2005,
#  2005,
#  2006,
#  2005,
#  2002,
#  2000,
#  2005,
#  2006,
#  2005,
#  2004,
#  1999,
#  2006,
#  2005,
#  2006,
#  2005,
#  2003,
#  1997,
#  2004,
#  2003,
#  2005,
#  2003,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2005,
#  2003,
#  2006,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2005,
#  1999,
#  2006,
#  2002,
#  2000,
#  1999,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2001,
#  1999,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2006,
#  2006,
#  2006,
#  1992,
#  2006,
#  2001,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2002,
#  2006,
#  2004,
#  2003,
#  2006,
#  2005,
#  2004,
#  2003,
#  2006,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2002,
#  2004,
#  2004,
#  2005,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  2000,
#  2004,
#  2006,
#  2005,
#  2006,
#  2000,
#  2002,
#  1999,
#  1999,
#  2005,
#  2002,
#  2003,
#  2003,
#  2006,
#  2005,
#  2005,
#  2005,
#  2003,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  1999,
#  2006,
#  2005,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2003,
#  2006,
#  2006,
#  2001,
#  2005,
#  2004,
#  2004,
#  2004,
#  2006,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2004,
#  2004,
#  2005,
#  2000,
#  2006,
#  2005,
#  2006,
#  2003,
#  1999,
#  2006,
#  2004,
#  2003,
#  2005,
#  2001,
#  2006,
#  2003,
#  2005,
#  1998,
#  2005,
#  2006,
#  2004,
#  2004,
#  2004,
#  2000,
#  2001,
#  1998,
#  2006,
#  2006,
#  2006,
#  1999,
#  2002,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2001,
#  2006,
#  2003,
#  2003,
#  2004,
#  2006,
#  2005,
#  1998,
#  2004,
#  2006,
#  2006,
#  2003,
#  2004,
#  2006,
#  2006,
#  1998,
#  2006,
#  2005,
#  2006,
#  2005,
#  2006,
#  2006,
#  2002,
#  2001,
#  2006,
#  2006,
#  2004,
#  1999,
#  2000,
#  2006,
#  2006,
#  2002,
#  2006,
#  2006,
#  2004,
#  2005,
#  2003,
#  2005,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2006,
#  2006,
#  2006,
#  2000,
#  2006,
#  2006,
#  2000,
#  2002,
#  2005,
#  2004,
#  2005,
#  2006,
#  2005,
#  2001,
#  2003,
#  2006,
#  2006,
#  2006,
#  2005,
#  2003,
#  2005,
#  2005,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2000,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  1998,
#  2003,
#  2006,
#  2006,
#  2004,
#  2005,
#  2006,
#  2004,
#  2001,
#  2006,
#  2006,
#  2002,
#  2006,
#  2002,
#  2004,
#  2006,
#  2006,
#  2006,
#  2005,
#  2005,
#  2006,
#  2002,
#  2004,
#  2000,
#  2006,
#  2004,
#  2006,
#  2001,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2004,
#  2006,
#  2005,
#  2005,
#  2006,
#  2006,
#  1999,
#  2004,
#  2006,
#  2006,
#  2005,
#  2001,
#  2004,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  1999,
#  2006,
#  1991,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2004,
#  1998,
#  2004,
#  2005,
#  2006,
#  2006,
#  2006,
#  2004,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2005,
#  2006,
#  2006,
#  2006,
#  2006,
#  2001,
#  2006,
#  2006,
#  1996]

# %%
dataset['year']=np.where(dataset['year']>up_lim,up_lim,np.where(dataset['year']<low_lim,low_lim,dataset['year']))
dataset
# Out:
#                                             full_name  selling_price  \
# 0                                     Maruti Alto Std       120000.0
# 1                              Hyundai Grand i10 Asta       550000.0
# 2                                    Hyundai i20 Asta       215000.0
# 3                       Maruti Alto K10 2010-2014 VXI       226000.0
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV       570000.0
# ...                                               ...            ...
# 19969                   Toyota Platinum Etios 1.4 GXD       650000.0
# 19970                          Maruti Ertiga BSIV VXI       925000.0
# 19971                    Skoda Rapid 1.5 TDI Elegance       425000.0
# 19972                          Mahindra XUV500 W6 2WD      1225000.0
# 19973                        Honda City i-VTEC CVT VX      1200000.0
#
#                                             new_price    year seller_type  \
# 0                                                NULL  2012.0  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 2                                                NULL  2010.0  Individual
# 3                                                NULL  2012.0  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# ...                                               ...     ...         ...
# 19969                                            NULL  2017.0      Dealer
# 19970                                            NULL  2019.0      Dealer
# 19971                                            NULL  2015.0      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016.0      Dealer
# 19973                                            NULL  2019.0      Dealer
#
#        km_driven   owner_type fuel_type transmission_type            mileage  \
# 0       120000.0  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1        20000.0  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2        60000.0  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3        37000.0  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4        30000.0  First Owner    Diesel            Manual  Mileage22.77 kmpl
# ...          ...          ...       ...               ...                ...
# 19969    69480.0  First Owner    Diesel            Manual  Mileage23.59 kmpl
# 19970    18000.0  First Owner    Petrol            Manual   Mileage17.5 kmpl
# 19971    67000.0  First Owner    Diesel            Manual  Mileage21.14 kmpl
# 19972  3800000.0  First Owner    Diesel            Manual   Mileage16.0 kmpl
# 19973    13000.0  First Owner    Petrol         Automatic   Mileage18.0 kmpl
#
#               engine            max_power   seats
# 0       Engine796 CC    Max Power46.3 bhp  Seats5
# 1      Engine1197 CC      Max Power82 bhp  Seats5
# 2      Engine1197 CC      Max Power80 bhp  Seats5
# 3       Engine998 CC    Max Power67.1 bhp  Seats5
# 4      Engine1498 CC   Max Power98.59 bhp  Seats5
# ...              ...                  ...     ...
# 19969  Engine1364 CC   Max Power67.05 bhp  Seats5
# 19970  Engine1373 CC    Max Power91.1 bhp  Seats7
# 19971  Engine1498 CC  Max Power103.52 bhp  Seats5
# 19972  Engine2179 CC     Max Power140 bhp  Seats7
# 19973  Engine1497 CC   Max Power117.6 bhp  Seats5
#
# [19974 rows x 13 columns]

# %%
plt.figure(figsize=(10,5))
dataset.boxplot('year')
plt.xticks(rotation=60)
plt.title('Box plot of year')
# Out:
# Text(0.5, 1.0, 'Box plot of year')

# %%
plt.boxplot(dataset['km_driven'])
plt.title('Box plot of Kilometer Driven')
# Out:
# Text(0.5, 1.0, 'Box plot of Kilometer Driven')

# %%
Q1=np.percentile(dataset['km_driven'], 25, interpolation = 'midpoint')
Q2=np.percentile(dataset['km_driven'], 50, interpolation = 'midpoint')
Q3=np.percentile(dataset['km_driven'], 75, interpolation = 'midpoint')
print("Q1 is : ", Q1)
print("Q2 is : ",Q2)
print("Q3 is : ",Q3)
# Out:
# Q1 is :  31117.0
# Q2 is :  52000.0
# Q3 is :  74000.0

# %%
IQR= Q3 - Q1
low_lim = Q1 - 1.5* IQR
up_lim = Q3 + 1.5 * IQR


print("IQR is : ",IQR)
print("Lower Limit is :",round(low_lim))
print("Upper limit is: ",round(up_lim))
# Out:
# IQR is :  42883.0
# Lower Limit is : -33208
# Upper limit is:  138324

# %%
outlier=[]
for x in dataset['km_driven']:
    if((x>up_lim) or(x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [185000.0,
#  190000.0,
#  160000.0,
#  160000.0,
#  240000.0,
#  165000.0,
#  185000.0,
#  280000.0,
#  220000.0,
#  170000.0,
#  162828.0,
#  250000.0,
#  142587.0,
#  160800.0,
#  350000.0,
#  155000.0,
#  140000.0,
#  160000.0,
#  150000.0,
#  280000.0,
#  155000.0,
#  143000.0,
#  200000.0,
#  187031.0,
#  170000.0,
#  163000.0,
#  208000.0,
#  148000.0,
#  160000.0,
#  190000.0,
#  175000.0,
#  144000.0,
#  150000.0,
#  174926.0,
#  150000.0,
#  140000.0,
#  387000.0,
#  150000.0,
#  215000.0,
#  228000.0,
#  200000.0,
#  150000.0,
#  170000.0,
#  150000.0,
#  140000.0,
#  185000.0,
#  170000.0,
#  170000.0,
#  162000.0,
#  148736.0,
#  186000.0,
#  215000.0,
#  147000.0,
#  147626.0,
#  160000.0,
#  227000.0,
#  200000.0,
#  250000.0,
#  160000.0,
#  170000.0,
#  145000.0,
#  150000.0,
#  155000.0,
#  187500.0,
#  140000.0,
#  200000.0,
#  295000.0,
#  242924.0,
#  160000.0,
#  190000.0,
#  200000.0,
#  177000.0,
#  150000.0,
#  158000.0,
#  184000.0,
#  230000.0,
#  215000.0,
#  186000.0,
#  142000.0,
#  158000.0,
#  145000.0,
#  140000.0,
#  164000.0,
#  200000.0,
#  174000.0,
#  145000.0,
#  165999.0,
#  191876.0,
#  500000.0,
#  177000.0,
#  140000.0,
#  257000.0,
#  190000.0,
#  210000.0,
#  161209.0,
#  142000.0,
#  198000.0,
#  160000.0,
#  225000.0,
#  176126.0,
#  180000.0,
#  195000.0,
#  168000.0,
#  167200.0,
#  150000.0,
#  140165.0,
#  161445.0,
#  230000.0,
#  187420.0,
#  190000.0,
#  165000.0,
#  164000.0,
#  170000.0,
#  150000.0,
#  175000.0,
#  255000.0,
#  220000.0,
#  570000.0,
#  190000.0,
#  150000.0,
#  180000.0,
#  142000.0,
#  204983.0,
#  175645.0,
#  150000.0,
#  170000.0,
#  147000.0,
#  183000.0,
#  199253.0,
#  143000.0,
#  168877.0,
#  197000.0,
#  220000.0,
#  168000.0,
#  280000.0,
#  211121.0,
#  240000.0,
#  315000.0,
#  277000.0,
#  461000.0,
#  217000.0,
#  158000.0,
#  170000.0,
#  180000.0,
#  138886.0,
#  150000.0,
#  780000.0,
#  173758.0,
#  145000.0,
#  154000.0,
#  200000.0,
#  146000.0,
#  208000.0,
#  151350.0,
#  140000.0,
#  148000.0,
#  190000.0,
#  186000.0,
#  142222.0,
#  163971.0,
#  156000.0,
#  350000.0,
#  160000.0,
#  270000.0,
#  154667.0,
#  139000.0,
#  152000.0,
#  142800.0,
#  140000.0,
#  140000.0,
#  160000.0,
#  276000.0,
#  140000.0,
#  198000.0,
#  150000.0,
#  150000.0,
#  142996.0,
#  147000.0,
#  209000.0,
#  182340.0,
#  185000.0,
#  141000.0,
#  150000.0,
#  158000.0,
#  233000.0,
#  270000.0,
#  400000.0,
#  850000.0,
#  361446.0,
#  150624.0,
#  228104.0,
#  150000.0,
#  162245.0,
#  216000.0,
#  185000.0,
#  160000.0,
#  200000.0,
#  162000.0,
#  139000.0,
#  138489.0,
#  171289.0,
#  139352.0,
#  140000.0,
#  150000.0,
#  185000.0,
#  153000.0,
#  192000.0,
#  147000.0,
#  150000.0,
#  220000.0,
#  178000.0,
#  147000.0,
#  160000.0,
#  275000.0,
#  151315.0,
#  180000.0,
#  199900.0,
#  159000.0,
#  146000.0,
#  170000.0,
#  212000.0,
#  150000.0,
#  175000.0,
#  158000.0,
#  147550.0,
#  200000.0,
#  190000.0,
#  200000.0,
#  254000.0,
#  200000.0,
#  145953.0,
#  300000.0,
#  150000.0,
#  200000.0,
#  150000.0,
#  150000.0,
#  160000.0,
#  425000.0,
#  150000.0,
#  200000.0,
#  312000.0,
#  210000.0,
#  144362.0,
#  154000.0,
#  190000.0,
#  170000.0,
#  160000.0,
#  144000.0,
#  160000.0,
#  173000.0,
#  230000.0,
#  158000.0,
#  280000.0,
#  185000.0,
#  192000.0,
#  150000.0,
#  270000.0,
#  161728.0,
#  157000.0,
#  200000.0,
#  214000.0,
#  150000.0,
#  145000.0,
#  293672.0,
#  200000.0,
#  310000.0,
#  165000.0,
#  146000.0,
#  155000.0,
#  149000.0,
#  165000.0,
#  148533.0,
#  180000.0,
#  190000.0,
#  144653.0,
#  170000.0,
#  151000.0,
#  221000.0,
#  180487.0,
#  295000.0,
#  140000.0,
#  153000.0,
#  143210.0,
#  141000.0,
#  191542.0,
#  198565.0,
#  179000.0,
#  220000.0,
#  140000.0,
#  140000.0,
#  160000.0,
#  300000.0,
#  162000.0,
#  300000.0,
#  170000.0,
#  140000.0,
#  155000.0,
#  299575.0,
#  142000.0,
#  180000.0,
#  300000.0,
#  222387.0,
#  175000.0,
#  145000.0,
#  200000.0,
#  157000.0,
#  200000.0,
#  180000.0,
#  260000.0,
#  293000.0,
#  190000.0,
#  169000.0,
#  333000.0,
#  180000.0,
#  175000.0,
#  194532.0,
#  146000.0,
#  185000.0,
#  150000.0,
#  170000.0,
#  230000.0,
#  156000.0,
#  830000.0,
#  155522.0,
#  148000.0,
#  140000.0,
#  181000.0,
#  175000.0,
#  140000.0,
#  144321.0,
#  150000.0,
#  150420.0,
#  163876.0,
#  151000.0,
#  143746.0,
#  151000.0,
#  233000.0,
#  390000.0,
#  179000.0,
#  145495.0,
#  175000.0,
#  165856.0,
#  195000.0,
#  300000.0,
#  180000.0,
#  165000.0,
#  200000.0,
#  214000.0,
#  146781.0,
#  720000.0,
#  180000.0,
#  140000.0,
#  170000.0,
#  349000.0,
#  288500.0,
#  177000.0,
#  160000.0,
#  145000.0,
#  189000.0,
#  195000.0,
#  590000.0,
#  200000.0,
#  280000.0,
#  150000.0,
#  220000.0,
#  150000.0,
#  140782.0,
#  200000.0,
#  150000.0,
#  277000.0,
#  210000.0,
#  150000.0,
#  193000.0,
#  500000.0,
#  149000.0,
#  140000.0,
#  200000.0,
#  140000.0,
#  163168.0,
#  200000.0,
#  400000.0,
#  250000.0,
#  290000.0,
#  171000.0,
#  178000.0,
#  212000.0,
#  160000.0,
#  288486.0,
#  140000.0,
#  160000.0,
#  229000.0,
#  200000.0,
#  180000.0,
#  479000.0,
#  169000.0,
#  138938.0,
#  150000.0,
#  180000.0,
#  146781.0,
#  200000.0,
#  140305.0,
#  205000.0,
#  211000.0,
#  150000.0,
#  150000.0,
#  160000.0,
#  252000.0,
#  142000.0,
#  199000.0,
#  170000.0,
#  181684.0,
#  260000.0,
#  150000.0,
#  250000.0,
#  186900.0,
#  150000.0,
#  140000.0,
#  139830.0,
#  160000.0,
#  161000.0,
#  950000.0,
#  150000.0,
#  150000.0,
#  165000.0,
#  140000.0,
#  225000.0,
#  180000.0,
#  250000.0,
#  350000.0,
#  150000.0,
#  142000.0,
#  165000.0,
#  196777.0,
#  340000.0,
#  167500.0,
#  143000.0,
#  154600.0,
#  182432.0,
#  185000.0,
#  675000.0,
#  200000.0,
#  185000.0,
#  140000.0,
#  147000.0,
#  360101.0,
#  143000.0,
#  145000.0,
#  190000.0,
#  150000.0,
#  170000.0,
#  480000.0,
#  199000.0,
#  260000.0,
#  420000.0,
#  525000.0,
#  245000.0,
#  143000.0,
#  750000.0,
#  480000.0,
#  143000.0,
#  170000.0,
#  157000.0,
#  165000.0,
#  825000.0,
#  147000.0,
#  177000.0,
#  200000.0,
#  150000.0,
#  240000.0,
#  197000.0,
#  187000.0,
#  160180.0,
#  140000.0,
#  215000.0,
#  315000.0,
#  156000.0,
#  203125.0,
#  820000.0,
#  186000.0,
#  213141.0,
#  173000.0,
#  148712.0,
#  150000.0,
#  175000.0,
#  145000.0,
#  210000.0,
#  156831.0,
#  200000.0,
#  213813.0,
#  1325000.0,
#  160000.0,
#  180000.0,
#  151000.0,
#  158648.0,
#  185000.0,
#  152000.0,
#  155000.0,
#  140000.0,
#  150000.0,
#  213000.0,
#  156000.0,
#  165000.0,
#  177000.0,
#  150000.0,
#  149028.0,
#  225000.0,
#  147500.0,
#  167000.0,
#  200000.0,
#  156000.0,
#  147000.0,
#  142500.0,
#  150000.0,
#  140000.0,
#  150000.0,
#  148000.0,
#  890000.0,
#  148000.0,
#  244400.0,
#  146000.0,
#  170000.0,
#  198000.0,
#  151768.0,
#  152358.0,
#  150821.0,
#  198000.0,
#  190000.0,
#  150000.0,
#  160000.0,
#  156000.0,
#  158000.0,
#  214000.0,
#  140000.0,
#  180000.0,
#  225000.0,
#  189000.0,
#  213000.0,
#  225000.0,
#  175000.0,
#  140451.0,
#  160000.0,
#  170000.0,
#  220000.0,
#  150000.0,
#  425785.0,
#  140000.0,
#  145000.0,
#  143000.0,
#  180000.0,
#  180000.0,
#  168986.0,
#  165000.0,
#  193000.0,
#  143448.0,
#  180000.0,
#  320000.0,
#  167919.0,
#  147000.0,
#  189000.0,
#  150000.0,
#  178000.0,
#  200000.0,
#  170000.0,
#  145000.0,
#  140000.0,
#  149500.0,
#  450000.0,
#  190000.0,
#  178000.0,
#  266007.0,
#  161823.0,
#  210000.0,
#  160000.0,
#  139000.0,
#  220000.0,
#  1485000.0,
#  225000.0,
#  250000.0,
#  450003.0,
#  139000.0,
#  170000.0,
#  177608.0,
#  200000.0,
#  200000.0,
#  190000.0,
#  150000.0,
#  200000.0,
#  140000.0,
#  160000.0,
#  174000.0,
#  157000.0,
#  145000.0,
#  160000.0,
#  179000.0,
#  163000.0,
#  172000.0,
#  147000.0,
#  151037.0,
#  151500.0,
#  200000.0,
#  223000.0,
#  193000.0,
#  175000.0,
#  153000.0,
#  147000.0,
#  189690.0,
#  200200.0,
#  145000.0,
#  142000.0,
#  146000.0,
#  170000.0,
#  140000.0,
#  186000.0,
#  158000.0,
#  148000.0,
#  195000.0,
#  170000.0,
#  140000.0,
#  155000.0,
#  150000.0,
#  200000.0,
#  176905.0,
#  270000.0,
#  148400.0,
#  140000.0,
#  140000.0,
#  150000.0,
#  151048.0,
#  270000.0,
#  180000.0,
#  150000.0,
#  190000.0,
#  220000.0,
#  140000.0,
#  170000.0,
#  3800000.0]

# %%
dataset['km_driven']=np.where(dataset['km_driven']>up_lim,up_lim,np.where(dataset['km_driven']<low_lim,low_lim,dataset['km_driven']))
dataset
# Out:
#                                             full_name  selling_price  \
# 0                                     Maruti Alto Std       120000.0
# 1                              Hyundai Grand i10 Asta       550000.0
# 2                                    Hyundai i20 Asta       215000.0
# 3                       Maruti Alto K10 2010-2014 VXI       226000.0
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV       570000.0
# ...                                               ...            ...
# 19969                   Toyota Platinum Etios 1.4 GXD       650000.0
# 19970                          Maruti Ertiga BSIV VXI       925000.0
# 19971                    Skoda Rapid 1.5 TDI Elegance       425000.0
# 19972                          Mahindra XUV500 W6 2WD      1225000.0
# 19973                        Honda City i-VTEC CVT VX      1200000.0
#
#                                             new_price    year seller_type  \
# 0                                                NULL  2012.0  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 2                                                NULL  2010.0  Individual
# 3                                                NULL  2012.0  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# ...                                               ...     ...         ...
# 19969                                            NULL  2017.0      Dealer
# 19970                                            NULL  2019.0      Dealer
# 19971                                            NULL  2015.0      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016.0      Dealer
# 19973                                            NULL  2019.0      Dealer
#
#        km_driven   owner_type fuel_type transmission_type            mileage  \
# 0       120000.0  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1        20000.0  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2        60000.0  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3        37000.0  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4        30000.0  First Owner    Diesel            Manual  Mileage22.77 kmpl
# ...          ...          ...       ...               ...                ...
# 19969    69480.0  First Owner    Diesel            Manual  Mileage23.59 kmpl
# 19970    18000.0  First Owner    Petrol            Manual   Mileage17.5 kmpl
# 19971    67000.0  First Owner    Diesel            Manual  Mileage21.14 kmpl
# 19972   138324.5  First Owner    Diesel            Manual   Mileage16.0 kmpl
# 19973    13000.0  First Owner    Petrol         Automatic   Mileage18.0 kmpl
#
#               engine            max_power   seats
# 0       Engine796 CC    Max Power46.3 bhp  Seats5
# 1      Engine1197 CC      Max Power82 bhp  Seats5
# 2      Engine1197 CC      Max Power80 bhp  Seats5
# 3       Engine998 CC    Max Power67.1 bhp  Seats5
# 4      Engine1498 CC   Max Power98.59 bhp  Seats5
# ...              ...                  ...     ...
# 19969  Engine1364 CC   Max Power67.05 bhp  Seats5
# 19970  Engine1373 CC    Max Power91.1 bhp  Seats7
# 19971  Engine1498 CC  Max Power103.52 bhp  Seats5
# 19972  Engine2179 CC     Max Power140 bhp  Seats7
# 19973  Engine1497 CC   Max Power117.6 bhp  Seats5
#
# [19974 rows x 13 columns]

# %%
plt.figure(figsize=(10,5))
dataset.boxplot('km_driven')
plt.xticks(rotation=60)
plt.title('Box plot of Kilometer Driven')
# Out:
# Text(0.5, 1.0, 'Box plot of Kilometer Driven')

# %% [markdown]
# #### Have checked and handled the outliers in the dataset using boxplot.

# %% [markdown]
# #### 4. Feature Engineering

# %% [markdown]
# ##### Creating new features, "Company" and 'brand' by replacing "full_name".

# %%
dataset['Company'] = dataset['full_name'].str.split(' ', expand=True)[0]

dataset['brand']=dataset.full_name.str.split(' ').str.get(1)
dataset
# Out:
#                                             full_name  selling_price  \
# 0                                     Maruti Alto Std       120000.0
# 1                              Hyundai Grand i10 Asta       550000.0
# 2                                    Hyundai i20 Asta       215000.0
# 3                       Maruti Alto K10 2010-2014 VXI       226000.0
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV       570000.0
# ...                                               ...            ...
# 19969                   Toyota Platinum Etios 1.4 GXD       650000.0
# 19970                          Maruti Ertiga BSIV VXI       925000.0
# 19971                    Skoda Rapid 1.5 TDI Elegance       425000.0
# 19972                          Mahindra XUV500 W6 2WD      1225000.0
# 19973                        Honda City i-VTEC CVT VX      1200000.0
#
#                                             new_price    year seller_type  \
# 0                                                NULL  2012.0  Individual
# 1        New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 2                                                NULL  2010.0  Individual
# 3                                                NULL  2012.0  Individual
# 4      New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# ...                                               ...     ...         ...
# 19969                                            NULL  2017.0      Dealer
# 19970                                            NULL  2019.0      Dealer
# 19971                                            NULL  2015.0      Dealer
# 19972  New Car (On-Road Price) : Rs.17.83-24.91 Lakh*  2016.0      Dealer
# 19973                                            NULL  2019.0      Dealer
#
#        km_driven   owner_type fuel_type transmission_type            mileage  \
# 0       120000.0  First Owner    Petrol            Manual   Mileage19.7 kmpl
# 1        20000.0  First Owner    Petrol            Manual   Mileage18.9 kmpl
# 2        60000.0  First Owner    Petrol            Manual   Mileage17.0 kmpl
# 3        37000.0  First Owner    Petrol            Manual  Mileage20.92 kmpl
# 4        30000.0  First Owner    Diesel            Manual  Mileage22.77 kmpl
# ...          ...          ...       ...               ...                ...
# 19969    69480.0  First Owner    Diesel            Manual  Mileage23.59 kmpl
# 19970    18000.0  First Owner    Petrol            Manual   Mileage17.5 kmpl
# 19971    67000.0  First Owner    Diesel            Manual  Mileage21.14 kmpl
# 19972   138324.5  First Owner    Diesel            Manual   Mileage16.0 kmpl
# 19973    13000.0  First Owner    Petrol         Automatic   Mileage18.0 kmpl
#
#               engine            max_power   seats   Company     brand
# 0       Engine796 CC    Max Power46.3 bhp  Seats5    Maruti      Alto
# 1      Engine1197 CC      Max Power82 bhp  Seats5   Hyundai     Grand
# 2      Engine1197 CC      Max Power80 bhp  Seats5   Hyundai       i20
# 3       Engine998 CC    Max Power67.1 bhp  Seats5    Maruti      Alto
# 4      Engine1498 CC   Max Power98.59 bhp  Seats5      Ford  Ecosport
# ...              ...                  ...     ...       ...       ...
# 19969  Engine1364 CC   Max Power67.05 bhp  Seats5    Toyota  Platinum
# 19970  Engine1373 CC    Max Power91.1 bhp  Seats7    Maruti    Ertiga
# 19971  Engine1498 CC  Max Power103.52 bhp  Seats5     Skoda     Rapid
# 19972  Engine2179 CC     Max Power140 bhp  Seats7  Mahindra    XUV500
# 19973  Engine1497 CC   Max Power117.6 bhp  Seats5     Honda      City
#
# [19974 rows x 15 columns]

# %%
dataset.drop(columns=['full_name'], axis=1, inplace=True)

# %% [markdown]
# #### Creating a new feature vehicle_age from year

# %%
dataset_year=2021
dataset['vehicle_age'] = dataset_year - dataset['year']
dataset.drop(['year'],axis=1, inplace=True)


dataset.head(2)
# Out:
#    selling_price                                     new_price seller_type  \
# 0       120000.0                                          NULL  Individual
# 1       550000.0  New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  Individual
#
#    km_driven   owner_type fuel_type transmission_type           mileage  \
# 0   120000.0  First Owner    Petrol            Manual  Mileage19.7 kmpl
# 1    20000.0  First Owner    Petrol            Manual  Mileage18.9 kmpl
#
#           engine          max_power   seats  Company  brand  vehicle_age
# 0   Engine796 CC  Max Power46.3 bhp  Seats5   Maruti   Alto          9.0
# 1  Engine1197 CC    Max Power82 bhp  Seats5  Hyundai  Grand          5.0

# %%
col_order=['Company', 'brand','vehicle_age','km_driven','seller_type','fuel_type','transmission_type','mileage','engine','max_power','seats','selling_price']
dataset=dataset[col_order]
dataset.head()
# Out:
#    Company     brand  vehicle_age  km_driven seller_type fuel_type  \
# 0   Maruti      Alto          9.0   120000.0  Individual    Petrol
# 1  Hyundai     Grand          5.0    20000.0  Individual    Petrol
# 2  Hyundai       i20         11.0    60000.0  Individual    Petrol
# 3   Maruti      Alto          9.0    37000.0  Individual    Petrol
# 4     Ford  Ecosport          6.0    30000.0      Dealer    Diesel
#
#   transmission_type            mileage         engine           max_power  \
# 0            Manual   Mileage19.7 kmpl   Engine796 CC   Max Power46.3 bhp
# 1            Manual   Mileage18.9 kmpl  Engine1197 CC     Max Power82 bhp
# 2            Manual   Mileage17.0 kmpl  Engine1197 CC     Max Power80 bhp
# 3            Manual  Mileage20.92 kmpl   Engine998 CC   Max Power67.1 bhp
# 4            Manual  Mileage22.77 kmpl  Engine1498 CC  Max Power98.59 bhp
#
#     seats  selling_price
# 0  Seats5       120000.0
# 1  Seats5       550000.0
# 2  Seats5       215000.0
# 3  Seats5       226000.0
# 4  Seats5       570000.0

# %%
dataset.dtypes
# Out:
# Company               object
# brand                 object
# vehicle_age          float64
# km_driven            float64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# selling_price        float64
# dtype: object

# %% [markdown]
# ### 5. Label Encoding
#
#                 Converting the labels into numeric form for the ease of Machine Learning models. Here the features of object type are changed into numerical values using encoding.

# %%
dataset.dtypes
# Out:
# Company               object
# brand                 object
# vehicle_age          float64
# km_driven            float64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage               object
# engine                object
# max_power             object
# seats                 object
# selling_price        float64
# dtype: object

# %%
## Loading Label Encoder function

from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

dataset.Company = le.fit_transform(dataset.Company)
dataset.brand = le.fit_transform(dataset.brand)
#dataset.selling_price = le.fit_transform(dataset.selling_price)
#dataset.new_price = le.fit_transform(dataset.new_price)
dataset.seller_type = le.fit_transform(dataset.seller_type)
dataset.fuel_type = le.fit_transform(dataset.fuel_type)
dataset.transmission_type = le.fit_transform(dataset.transmission_type)
dataset.engine = le.fit_transform(dataset.engine)
dataset.max_power = le.fit_transform(dataset.max_power)
dataset.seats = le.fit_transform(dataset.seats)
dataset.mileage = le.fit_transform(dataset.mileage)
#dataset.owner_type = le.fit_transform(dataset.owner_type)


dataset
# Out:
#        Company  brand  vehicle_age  km_driven  seller_type  fuel_type  \
# 0           24     20          9.0   120000.0            1          4
# 1           13    113          5.0    20000.0            1          4
# 2           13    271         11.0    60000.0            1          4
# 3           24     20          9.0    37000.0            1          4
# 4           11     80          6.0    30000.0            0          1
# ...        ...    ...          ...        ...          ...        ...
# 19969       39    171          4.0    69480.0            0          1
# 19970       24     85          2.0    18000.0            0          4
# 19971       37    184          6.0    67000.0            0          1
# 19972       23    259          5.0   138324.5            0          1
# 19973       12     61          2.0    13000.0            0          4
#
#        transmission_type  mileage  engine  max_power  seats  selling_price
# 0                      1      359     159        316      5       120000.0
# 1                      1      322      12        424      5       550000.0
# 2                      1      238      12        417      5       215000.0
# 3                      1      404     167        377      5       226000.0
# 4                      1      456      43        482      5       570000.0
# ...                  ...      ...     ...        ...    ...            ...
# 19969                  1      472      23        375      5       650000.0
# 19970                  1      263      25        461      7       925000.0
# 19971                  1      414      43         14      5       425000.0
# 19972                  1      200      82         96      7      1225000.0
# 19973                  0      286      42         51      5      1200000.0
#
# [19974 rows x 12 columns]

# %%
dataset.dtypes
# Out:
# Company                int32
# brand                  int32
# vehicle_age          float64
# km_driven            float64
# seller_type            int32
# fuel_type              int32
# transmission_type      int32
# mileage                int32
# engine                 int32
# max_power              int32
# seats                  int32
# selling_price        float64
# dtype: object

# %% [markdown]
# ##### The object features in the column are changed into numerical datatypes by using encoding function.

# %% [markdown]
# #### Feature reduction
#             As more than 50% of the values in the column new_price are null, we can drop the column.
#             The column owner_type is having a single value, which may not contribute to the data set modelling.

# %%
## Dropping unwanted columns in the dataset

dataset.drop(columns=['seller_type'], axis=1, inplace=True)
dataset.head()
# Out:
#    Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0       24     20          9.0   120000.0          4                  1
# 1       13    113          5.0    20000.0          4                  1
# 2       13    271         11.0    60000.0          4                  1
# 3       24     20          9.0    37000.0          4                  1
# 4       11     80          6.0    30000.0          1                  1
#
#    mileage  engine  max_power  seats  selling_price
# 0      359     159        316      5       120000.0
# 1      322      12        424      5       550000.0
# 2      238      12        417      5       215000.0
# 3      404     167        377      5       226000.0
# 4      456      43        482      5       570000.0

# %%
data=pd.DataFrame(dataset.groupby("Company")['selling_price'].median())
data.reset_index()
# Out:
#     Company  selling_price
# 0         0       133000.0
# 1         1      1799500.0
# 2         2      2200000.0
# 3         3     11300000.0
# 4         4       232000.0
# 5         5      1192500.0
# 6         6        78000.0
# 7         7       300000.0
# 8         8     39500000.0
# 9         9       300000.0
# 10       10       600000.0
# 11       11       530000.0
# 12       12       560000.0
# 13       13       485000.0
# 14       14      1897500.0
# 15       15      1225000.0
# 16       16      2795000.0
# 17       17      1598000.0
# 18       18      1549000.0
# 19       19     15000000.0
# 20       20      3245000.0
# 21       21      4600000.0
# 22       22      1770000.0
# 23       23       690000.0
# 24       24       449000.0
# 25       25      6100000.0
# 26       26      5100000.0
# 27       27      2150000.0
# 28       28      2150000.0
# 29       29       875000.0
# 30       30       425000.0
# 31       31       150000.0
# 32       32       150000.0
# 33       33      5975000.0
# 34       34       255000.0
# 35       35       400000.0
# 36       36     24200000.0
# 37       37       535000.0
# 38       38       360000.0
# 39       39       965000.0
# 40       40       525000.0
# 41       41      1825000.0

# %%
data = dataset.merge(data, on='Company', how='left')
data.head()
# Out:
#    Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0       24     20          9.0   120000.0          4                  1
# 1       13    113          5.0    20000.0          4                  1
# 2       13    271         11.0    60000.0          4                  1
# 3       24     20          9.0    37000.0          4                  1
# 4       11     80          6.0    30000.0          1                  1
#
#    mileage  engine  max_power  seats  selling_price_x  selling_price_y
# 0      359     159        316      5         120000.0         449000.0
# 1      322      12        424      5         550000.0         485000.0
# 2      238      12        417      5         215000.0         485000.0
# 3      404     167        377      5         226000.0         449000.0
# 4      456      43        482      5         570000.0         530000.0

# %%
dataset['Annualselling_price']= data['selling_price_y']
dataset.head(3)
# Out:
#    Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0       24     20          9.0   120000.0          4                  1
# 1       13    113          5.0    20000.0          4                  1
# 2       13    271         11.0    60000.0          4                  1
#
#    mileage  engine  max_power  seats  selling_price  Annualselling_price
# 0      359     159        316      5       120000.0             449000.0
# 1      322      12        424      5       550000.0             485000.0
# 2      238      12        417      5       215000.0             485000.0

# %%
dataset.shape
# Out:
# (19974, 12)

# %%
dataset.describe().T
# Out:
#                        count           mean            std      min       25%  \
# Company              19974.0      21.680785      10.593036      0.0      13.0
# brand                19974.0     145.048914      84.295911      0.0      70.0
# vehicle_age          19974.0       6.424001       3.092639      0.0       4.0
# km_driven            19974.0   56009.429659   32314.861419    100.0   31114.0
# fuel_type            19974.0       2.457845       1.517765      0.0       1.0
# transmission_type    19974.0       0.802293       0.398280      0.0       1.0
# mileage              19974.0     330.059477     137.330829      0.0     238.0
# engine               19974.0      58.165365      53.195586      0.0      14.0
# max_power            19974.0     303.543156     159.669664      0.0     147.0
# seats                19974.0       5.284770       0.896714      0.0       5.0
# selling_price        19974.0  739294.478522  910400.112543  25000.0  340000.0
# Annualselling_price  19974.0  659913.237208  636992.987262  78000.0  449000.0
#
#                           50%       75%         max
# Company                  24.0      24.0        41.0
# brand                   132.0     218.0       273.0
# vehicle_age               6.0       8.0        14.0
# km_driven             52000.0   74000.0    138324.5
# fuel_type                 1.0       4.0         4.0
# transmission_type         1.0       1.0         1.0
# mileage                 342.0     451.0       561.0
# engine                   42.0      82.0       169.0
# max_power               377.0     424.0       493.0
# seats                     5.0       5.0         9.0
# selling_price        520000.0  785000.0  39500000.0
# Annualselling_price  485000.0  560000.0  39500000.0

# %%
## Prediction Target:

dataset['Prediction'] = np.where(data[[ 'km_driven', 'mileage', 'max_power', 'seats', 'engine',
       'transmission_type', 'fuel_type']].sum(axis=1)>dataset['Annualselling_price'], 1, 0)

dataset.head()
# Out:
#    Company  brand  vehicle_age  km_driven  fuel_type  transmission_type  \
# 0       24     20          9.0   120000.0          4                  1
# 1       13    113          5.0    20000.0          4                  1
# 2       13    271         11.0    60000.0          4                  1
# 3       24     20          9.0    37000.0          4                  1
# 4       11     80          6.0    30000.0          1                  1
#
#    mileage  engine  max_power  seats  selling_price  Annualselling_price  \
# 0      359     159        316      5       120000.0             449000.0
# 1      322      12        424      5       550000.0             485000.0
# 2      238      12        417      5       215000.0             485000.0
# 3      404     167        377      5       226000.0             449000.0
# 4      456      43        482      5       570000.0             530000.0
#
#    Prediction
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
dataset.describe(include='all')
# Out:
#             Company         brand   vehicle_age      km_driven     fuel_type  \
# count  19974.000000  19974.000000  19974.000000   19974.000000  19974.000000
# mean      21.680785    145.048914      6.424001   56009.429659      2.457845
# std       10.593036     84.295911      3.092639   32314.861419      1.517765
# min        0.000000      0.000000      0.000000     100.000000      0.000000
# 25%       13.000000     70.000000      4.000000   31114.000000      1.000000
# 50%       24.000000    132.000000      6.000000   52000.000000      1.000000
# 75%       24.000000    218.000000      8.000000   74000.000000      4.000000
# max       41.000000    273.000000     14.000000  138324.500000      4.000000
#
#        transmission_type       mileage        engine     max_power  \
# count       19974.000000  19974.000000  19974.000000  19974.000000
# mean            0.802293    330.059477     58.165365    303.543156
# std             0.398280    137.330829     53.195586    159.669664
# min             0.000000      0.000000      0.000000      0.000000
# 25%             1.000000    238.000000     14.000000    147.000000
# 50%             1.000000    342.000000     42.000000    377.000000
# 75%             1.000000    451.000000     82.000000    424.000000
# max             1.000000    561.000000    169.000000    493.000000
#
#               seats  selling_price  Annualselling_price    Prediction
# count  19974.000000   1.997400e+04         1.997400e+04  19974.000000
# mean       5.284770   7.392945e+05         6.599132e+05      0.000050
# std        0.896714   9.104001e+05         6.369930e+05      0.007076
# min        0.000000   2.500000e+04         7.800000e+04      0.000000
# 25%        5.000000   3.400000e+05         4.490000e+05      0.000000
# 50%        5.000000   5.200000e+05         4.850000e+05      0.000000
# 75%        5.000000   7.850000e+05         5.600000e+05      0.000000
# max        9.000000   3.950000e+07         3.950000e+07      1.000000

# %%
dataset.shape
# Out:
# (19974, 13)

# %% [markdown]
# ### Exploratory  Data Analysis

# %%
dataset.columns
# Out:
# Index(['Company', 'brand', 'vehicle_age', 'km_driven', 'fuel_type',
#        'transmission_type', 'mileage', 'engine', 'max_power', 'seats',
#        'selling_price', 'Annualselling_price', 'Prediction'],
#       dtype='object')

# %% [markdown]
# #### Univariate Analysis:

# %% [markdown]
# ###### Plot of Top 10 most present company names in the dataset:

# %%
## Plot of Top 10 most present company names in the dataset:

fig = plt.figure(figsize=(9,3))
gs = fig.add_gridspec(1,1)

cars = dataset.Company.value_counts().head(10)
pal = sns.light_palette('#79c6e8', n_colors=50, reverse=True)
pal[0] = '#9c9a9a'
ax = fig.add_subplot(gs[0,0])
ax=sns.barplot(x=cars.index, y=cars.values, edgecolor='k', linewidth=0.7, palette=pal)
ax.tick_params(axis='x', labelsize=5, rotation=90)
ax.tick_params(axis='y', labelsize=5, left=False)
ax.set_ylabel(ylabel='count', fontsize=8, weight='bold')

for p in ax.patches:
    value = f'{p.get_height():,.0f}'
    x = p.get_x() + p.get_width()/2
    y = p.get_y() + p.get_height()+320
    ax.text(x=x, y=y, s=value, fontsize=4.5, ha='center', va='center',
           bbox=dict(fc='white', edgecolor='k', boxstyle='round', linewidth=0.5))
    
fig.suptitle(t='Top 10 most present company names in the dataset', fontsize='8', weight='bold')
sns.despine()
plt.show()

# %% [markdown]
# ##### Plot of Top 10 years with highest sales:

# %%
fig = plt.figure(figsize=(12,4))
gs = fig.add_gridspec(1,1)

cars = dataset.vehicle_age.value_counts().head(10)
pal = sns.light_palette('#79c6e8', n_colors=50, reverse=True)
pal[7] = '#9c9a9a'
ax = fig.add_subplot(gs[0,0])
ax=sns.barplot(x=cars.index, y=cars.values, edgecolor='k', linewidth=0.7, palette=pal)
ax.tick_params(axis='x', labelsize=5, rotation=90)
ax.tick_params(axis='y', labelsize=5, left=False)
ax.set_ylabel(ylabel='count', fontsize=7, weight='bold')

for p in ax.patches:
    value = f'{p.get_height():,.0f}'
    x = p.get_x() + p.get_width()/2
    y = p.get_y() + p.get_height()+150
    ax.text(x=x, y=y, s=value, fontsize=6.5, ha='center', va='center',
           bbox=dict(fc='white', edgecolor='k', boxstyle='round', linewidth=0.5))
    
fig.suptitle(t='Top 10 years with highest sales', fontsize='8', weight='bold')
sns.despine()
plt.show()

# %% [markdown]
# ##### Bivariate Analysis:

# %% [markdown]
# #### Plot of ## Plot of Top 10

# %%
fig = plt.figure(figsize=(12,4))
gs = fig.add_gridspec(1,1)

pal = sns.light_palette('#79c6e8', reverse=True, n_colors=50)
pal.insert(0,'#9c9a9a')

cars = dataset.groupby('Company')['selling_price'].mean().sort_values(ascending=False).head(10)/1000000
ax = fig.add_subplot(gs[0,0])
ax=sns.barplot(x=cars.index, y=cars.values, edgecolor='k', linewidth=0.7, palette=pal)
ax.tick_params(axis='x', labelsize=5, rotation=90)
ax.tick_params(axis='y', labelsize=5, left=False)
ax.set_xlabel(xlabel=None)
ax.set_ylabel(ylabel='price in millions', fontsize=8, weight='bold')
for p in ax.patches:
    value = f'{p.get_height():,.1f}' + ' M'
    x = p.get_x() + p.get_width()/2
    y = p.get_y() + p.get_height()+3
    ax.text(x=x, y=y, s=value, fontsize=6.5, ha='center', va='center',
           bbox=dict(fc='white', edgecolor='k', boxstyle='round', linewidth=0.5))
    
fig.suptitle(t='Top 10 car company with highest selling price', fontsize=8, weight='bold')
sns.despine()
plt.show()

# %%
fig = plt.figure(figsize=(7,3))
gs = fig.add_gridspec(1,1)

pal = sns.light_palette('#79c6e8', reverse=True, n_colors=50)
pal.insert(0,'#9c9a9a')

cars = dataset.groupby('Company')['max_power'].mean().sort_values(ascending=False).head(10)
color = ['skyblue' for i in range(15)]
color[0] = 'grey'
ax = fig.add_subplot(gs[0,0])
ax=sns.barplot(x=cars.index, y=cars.values, edgecolor='k', linewidth=0.7, palette=pal)
ax.tick_params(axis='x', labelsize=5, rotation=90)
ax.tick_params(axis='y', labelsize=5, left=False)
ax.set_xlabel(xlabel=None)
ax.set_ylabel(ylabel='max power in bhp', fontsize=8, weight='bold')
for p in ax.patches:
    value = f'{p.get_height():,.0f}'
    x = p.get_x() + p.get_width()/2
    y = p.get_y() + p.get_height()+38
    ax.text(x=x, y=y, s=value, fontsize=6, ha='center', va='center',
           bbox=dict(fc='white', edgecolor='k', boxstyle='round', linewidth=0.5))
    
fig.suptitle(t='Top 10 car company with highest max power', fontsize=8, weight='bold')
sns.despine()
plt.show()

# %%
corrmatrix=dataset.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,annot=True,vmin=-0.2,vmax=0.8,linewidth=0.2,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Insights:
#
#                 From the correlation matrix, it is clear that there is a high correlation between Annual selling price and selling price dependancy along with other variables.

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ##### Splitting of data

# %%
X=dataset.drop(['Prediction'],axis=1)
y=dataset['Prediction']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42, test_size=0.20)

# %%
X_train.shape
# Out:
# (15979, 12)

# %%
y_train.shape
# Out:
# (15979,)

# %%
X_test.shape
# Out:
# (3995, 12)

# %%
y_test.shape
# Out:
# (3995,)

# %% [markdown]
# ### To find out the best classification model which is accurate :
#             Some of the famous classification models are :
#
#                     1. Logistic Regression Model
#                     2. K-Nearest Neighbor(KNN) Model
#                     3. Random Forest Model
#                     4. Decision Tree Model
#                     5. Support Vector Machine (SVM) Model
#                     6. Gradient Boosting

# %% [markdown]
# #### 1. Logistic Regression Model:

# %%
log_reg= LogisticRegression()
model = log_reg.fit(X_train, y_train)
y_pred=log_reg.predict(X_test)

# %%
print('Accuracy of Logistic Regression model is :',accuracy_score(y_test,y_pred)*100)
print("Precision is :",precision_score(y_test,y_pred,average='weighted'))
print("Recall is : ",recall_score(y_test,y_pred,average='weighted'))
print("F1 Score is :",f1_score(y_test,y_pred,average='weighted'))
# Out:
# Accuracy of Logistic Regression model is : 100.0
# Precision is : 1.0
# Recall is :  1.0
# F1 Score is : 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3995]], dtype=int64)

# %% [markdown]
# #### 2. K- Nearest Neighbors (KNN) Model

# %%
model = KNeighborsClassifier(n_neighbors=3) 
model.fit(X_train,y_train)
prediction = model.predict(X_test)

# %%
print('The accuracy of KNN model is : ', accuracy_score(prediction,y_test)*100)
print("Precision is : ",precision_score(prediction,y_test,average = 'weighted'))
print("Recall is : ",recall_score(prediction,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(prediction,y_test,average ='weighted'))
# Out:
# The accuracy of KNN model is :  100.0
# Precision is :  1.0
# Recall is :  1.0
# F1 Score is :  1.0

# %%
confusion_matrix(prediction,y_test)
# Out:
# array([[3995]], dtype=int64)

# %% [markdown]
# #### 3. Random Forest Model:

# %%
rnf = RandomForestClassifier(n_estimators=100)
rnf_model = rnf.fit(X_train, y_train)
rnf_predict = rnf_model.predict(X_test)

# %%
rnf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rnf_predict=rnf.predict(X_test)

# %%
print('Accuracy of Random Forest model is : ',accuracy_score(rnf_predict, y_test) *100)
print("Precision is : ",precision_score(rnf_predict,y_test,average = 'weighted'))
print("Recall is : ",recall_score(rnf_predict,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(rnf_predict,y_test,average ='weighted'))
# Out:
# Accuracy of Random Forest model is :  100.0
# Precision is :  1.0
# Recall is :  1.0
# F1 Score is :  1.0

# %%
confusion_matrix(y_test,rnf_predict)
# Out:
# array([[3995]], dtype=int64)

# %% [markdown]
# ####  4. Decision Tree Model:

# %%
dtree = DecisionTreeClassifier()
dtree_model = dtree.fit(X_train, y_train)
dtree_predict = dtree.predict(X_test)

# %%
print('Accuracy of Decision Tree model is : ', accuracy_score(dtree_predict, y_test)*100)
print("Precision is : ",precision_score(dtree_predict,y_test,average = 'weighted'))
print("Recall is : ",recall_score(dtree_predict,y_test,average = 'weighted'))
print("F1 Score is : ",f1_score(dtree_predict,y_test,average ='weighted'))
# Out:
# Accuracy of Decision Tree model is :  100.0
# Precision is :  1.0
# Recall is :  1.0
# F1 Score is :  1.0

# %%
confusion_matrix(y_test,dtree_predict)
# Out:
# array([[3995]], dtype=int64)

# %% [markdown]
# #### 5. Support Vector Machine Model:

# %%
from sklearn import svm 
from sklearn.svm import SVC

# %%
svm_linear=SVC(kernel='linear')
svm_linear.fit(X_train,y_train)
pred=svm_linear.predict(X_test)

# %%
print('The accuracy of Support Vector Machine model is: ', accuracy_score(pred,y_test)*100)
print("Precision is : ",precision_score(pred,y_test,average='weighted'))
print("Recall is : ",recall_score(pred,y_test,average='weighted'))
print("F1 Score is : ",f1_score(pred,y_test,average='weighted'))
# Out:
# The accuracy of Support Vector Machine model is:  100.0
# Precision is :  1.0
# Recall is :  1.0
# F1 Score is :  1.0

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[3995]], dtype=int64)

# %% [markdown]
# #### 6. Linear Regression Model:

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train , y_train)

#train , test = train_test_split(dataset , test_size=0.2)
#train_X = train.drop(['selling_price'] , axis=1)
#test_x= test.drop(['selling_price'] , axis=1)
#train_y = train.selling_price
#test_y = test.selling_price

pred = lin_reg.predict(X_test)
error = pred- y_test
mse = np.mean(np.square(error))
mae = np.mean(np.abs(error*100/y_test))
print("MSE :" ,mse)
print("MAPE :", mae)
print("Acuracy :", 100 -mae)
# Out:
# MSE : 8.044528027729655e-08
# MAPE : inf
# Acuracy : -inf

# %% [markdown]
# ### Feature Scaling:

# %%
X1 = X
X.describe()
# Out:
#             Company         brand   vehicle_age      km_driven     fuel_type  \
# count  19974.000000  19974.000000  19974.000000   19974.000000  19974.000000
# mean      21.680785    145.048914      6.424001   56009.429659      2.457845
# std       10.593036     84.295911      3.092639   32314.861419      1.517765
# min        0.000000      0.000000      0.000000     100.000000      0.000000
# 25%       13.000000     70.000000      4.000000   31114.000000      1.000000
# 50%       24.000000    132.000000      6.000000   52000.000000      1.000000
# 75%       24.000000    218.000000      8.000000   74000.000000      4.000000
# max       41.000000    273.000000     14.000000  138324.500000      4.000000
#
#        transmission_type       mileage        engine     max_power  \
# count       19974.000000  19974.000000  19974.000000  19974.000000
# mean            0.802293    330.059477     58.165365    303.543156
# std             0.398280    137.330829     53.195586    159.669664
# min             0.000000      0.000000      0.000000      0.000000
# 25%             1.000000    238.000000     14.000000    147.000000
# 50%             1.000000    342.000000     42.000000    377.000000
# 75%             1.000000    451.000000     82.000000    424.000000
# max             1.000000    561.000000    169.000000    493.000000
#
#               seats  selling_price  Annualselling_price
# count  19974.000000   1.997400e+04         1.997400e+04
# mean       5.284770   7.392945e+05         6.599132e+05
# std        0.896714   9.104001e+05         6.369930e+05
# min        0.000000   2.500000e+04         7.800000e+04
# 25%        5.000000   3.400000e+05         4.490000e+05
# 50%        5.000000   5.200000e+05         4.850000e+05
# 75%        5.000000   7.850000e+05         5.600000e+05
# max        9.000000   3.950000e+07         3.950000e+07

# %%
scalar = StandardScaler()

# %%
X1=scalar.fit_transform(X1)
X1=pd.DataFrame(X1)

X1.describe()
# Out:
#                  0             1             2             3             4   \
# count  1.997400e+04  1.997400e+04  1.997400e+04  1.997400e+04  1.997400e+04
# mean   8.610593e-16 -1.554946e-16  4.269139e-16  6.890119e-17  2.817857e-16
# std    1.000025e+00  1.000025e+00  1.000025e+00  1.000025e+00  1.000025e+00
# min   -2.046753e+00 -1.720754e+00 -2.077242e+00 -1.730189e+00 -1.619425e+00
# 25%   -8.195008e-01 -8.903254e-01 -7.838165e-01 -7.704212e-01 -9.605452e-01
# 50%    2.189432e-01 -1.548028e-01 -1.371035e-01 -1.240770e-01 -9.605452e-01
# 75%    2.189432e-01  8.654383e-01  5.096094e-01  5.567414e-01  1.016095e+00
# max    1.823811e+00  1.517918e+00  2.449748e+00  2.547346e+00  1.016095e+00
#
#                  5             6             7             8             9   \
# count  1.997400e+04  1.997400e+04  1.997400e+04  1.997400e+04  1.997400e+04
# mean   3.317818e-15 -1.280531e-16 -1.342339e-17 -7.930085e-16 -4.700967e-16
# std    1.000025e+00  1.000025e+00  1.000025e+00  1.000025e+00  1.000025e+00
# min   -2.014445e+00 -2.403450e+00 -1.093452e+00 -1.901117e+00 -5.893629e+00
# 25%    4.964146e-01 -6.703650e-01 -8.302657e-01 -9.804434e-01 -3.175786e-01
# 50%    4.964146e-01  8.694932e-02 -3.038931e-01  4.600666e-01 -3.175786e-01
# 75%    4.964146e-01  8.806730e-01  4.480679e-01  7.544317e-01 -3.175786e-01
# max    4.964146e-01  1.681679e+00  2.083583e+00  1.186585e+00  4.143262e+00
#
#                  10            11
# count  1.997400e+04  1.997400e+04
# mean  -4.737374e-17 -6.046502e-17
# std    1.000025e+00  1.000025e+00
# min   -7.846137e-01 -9.135545e-01
# 25%   -4.386033e-01 -3.311159e-01
# 50%   -2.408831e-01 -2.745990e-01
# 75%    5.020503e-02 -1.568553e-01
# max    4.257653e+01  6.097565e+01

# %% [markdown]
# ### Fine Tuning of hyperparameters:
#
#          It is done by setting a value prior to the process. But here we have obtained accuracy for all the models are high so there is no need of fine tuning.

# %%
rft=RandomForestClassifier(n_estimators=850,max_depth=100, random_state=30, criterion='entropy', max_features='sqrt')

# %%
rft.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=100, max_features='sqrt',
#                        n_estimators=850, random_state=30)

# %%
y_pred=rft.predict(X_test)
f1_score(y_test,y_pred,average='weighted')
# Out:
# 1.0

# %% [markdown]
# #### Insights:
#        As the accuracy afte fine tuning doesn't have any importance for this dataset modeling.
#        It has obtained 100% accuacy in the classiication models like Logistic Regression and Support Vector Machine.
#        An accuracy of 99% above is obtained for KNN, Radom Forest and Decision Tree models also done after standard scaling.
